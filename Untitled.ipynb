# %%
import pandas as pd

# %%
tr2=pd.read_csv('train1.csv')

# %%
p=tr2[tr2.label==1].shape[0]

# %%
n=tr2[tr2.label==0].shape[0]

# %%
n
# Out:
# 5894

# %%
p
# Out:
# 2026

# %%
pp=p/(p+n)

# %%
np=n/(p+n)

# %%
np
# Out:
# 0.7441919191919192

# %%
pp
# Out:
# 0.2558080808080808

# %%
import matplotlib.pyplot as plt
color_palette_list = ['#FFB300','#FFE082']
fig, ax = plt.subplots()
plt.rcParams['text.color'] = '#000000'
plt.rcParams['axes.labelcolor']= '#000000'
plt.rcParams['xtick.color'] = '#000000'
plt.rcParams['ytick.color'] = '#000000'
plt.rcParams['font.size']=19
labels = ['Negative Tweets', 
         'Positive Tweets']
percentages = [74.4191, 25.5808]
explode=(0.1,0)
ax.pie(percentages, explode=explode, labels=labels,  
       colors=color_palette_list[0:2], autopct='%1.0f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.45)
ax.axis('equal')
ax.legend(frameon=True, bbox_to_anchor=(1.6,0.8))
